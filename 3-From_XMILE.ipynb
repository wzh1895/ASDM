# %%
from ASDM.Engine import Structure

# %%
# model = Structure(from_xmile='BuiltInTestModels/Goal_gap.stmx')
# model = Structure(from_xmile='BuiltInTestModels/Goal_gap_array.stmx')
# model = Structure(from_xmile='BuiltInTestModels/Built_in_vars.stmx')
# model = Structure(from_xmile='BuiltInTestModels/IF_THEN_ELSE.stmx')
# model = Structure(from_xmile='BuiltInTestModels/Graph_function.stmx ')
model = Structure(from_xmile='BuiltInTestModels/Conveyor.stmx ')
# Out:
# Engine: adding element: Conveyor_1 equation: <ASDM.Engine.Conveyor object at 0x000001C1300BEAF0>
# Engine: adding element: Flow_Out equation: 0
# Engine: adding element: Flow_In equation: 6

# %%
model.clear_last_run()
model.simulate()
df_outcome = model.export_simulation_result()
df_outcome
# Out:
#      TIME  Conveyor_1  Flow_Out  Flow_In
# 0    1.00       12.00       1.0        6
# 1    1.25       13.25       1.0        6
# 2    1.50       14.50       1.0        6
# 3    1.75       15.75       1.0        6
# 4    2.00       17.00       1.0        6
# 5    2.25       18.25       1.0        6
# 6    2.50       19.50       1.0        6
# 7    2.75       20.75       1.0        6
# 8    3.00       22.00       1.0        6
# 9    3.25       23.25       1.0        6
# 10   3.50       24.50       1.0        6
# 11   3.75       25.75       1.0        6
# 12   4.00       27.00       1.0        6
# 13   4.25       28.25       1.0        6
# 14   4.50       29.50       1.0        6
# 15   4.75       30.75       1.0        6
# 16   5.00       32.00       1.0        6
# 17   5.25       33.25       1.0        6
# 18   5.50       34.50       1.0        6
# 19   5.75       35.75       1.0        6
# 20   6.00       37.00       1.0        6
# 21   6.25       38.25       1.0        6
# 22   6.50       39.50       1.0        6
# 23   6.75       40.75       1.0        6
# 24   7.00       42.00       1.0        6
# 25   7.25       43.25       1.0        6
# 26   7.50       44.50       1.0        6
# 27   7.75       45.75       1.0        6
# 28   8.00       47.00       1.0        6
# 29   8.25       48.25       1.0        6
# 30   8.50       49.50       1.0        6
# 31   8.75       50.75       1.0        6
# 32   9.00       52.00       1.0        6
# 33   9.25       53.25       1.0        6
# 34   9.50       54.50       1.0        6
# 35   9.75       55.75       1.0        6
# 36  10.00       57.00       1.0        6
# 37  10.25       58.25       1.0        6
# 38  10.50       59.50       1.0        6
# 39  10.75       60.75       1.0        6
# 40  11.00       62.00       1.0        6
# 41  11.25       63.25       1.0        6
# 42  11.50       64.50       1.0        6
# 43  11.75       65.75       1.0        6
# 44  12.00       67.00       1.0        6
# 45  12.25       68.25       1.0        6
# 46  12.50       69.50       1.0        6
# 47  12.75       70.75       1.0        6
# 48  13.00       72.00       6.0        6

# %%
# df_outcome[['Goal', 'Stock']].plot()
df_outcome.plot()
# Out:
# <AxesSubplot:>
