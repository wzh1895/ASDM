# %%
from ASDM.Engine import Structure

# %%
# model = Structure(from_xmile='BuiltInTestModels/Goal_gap.stmx')
model = Structure(from_xmile='BuiltInTestModels/Goal_gap_array.stmx')
# Out:
# {'Dim1': ['1', '2'], 'Dim2': ['First', 'Second']}
# Engine: adding element: Stock equation: <ASDM.Engine.SubscriptIndexer object at 0x0000026FEA9BEAF0>
# Engine: adding element: Goal equation: 20
# Engine: adding element: Gap equation: <ASDM.Engine.SubscriptIndexer object at 0x0000026FEA9FDF10>
# Engine: adding element: AT equation: <ASDM.Engine.SubscriptIndexer object at 0x0000026FEA9FDF10>
# Engine: adding element: Flow equation: <ASDM.Engine.SubscriptIndexer object at 0x0000026FEA9FDF10>

# %%
model.clear_last_run()
model.simulate(simulation_time=1, dt=0.25)
df_outcome = model.export_simulation_result()
df_outcome
# Out:
# Stock
#    TIME  (Stock, (1, First))  (Stock, (1, Second))  (Stock, (2, First))  \
# 0  0.00             100.0000            100.000000             100.0000
# 1  0.25              80.0000             93.333333              96.0000
# 2  0.50              65.0000             87.222222              92.2000
# 3  0.75              53.7500             81.620370              88.5900
# 4  1.00              45.3125             76.485340              85.1605
#
#    (Stock, (2, Second))  (Goal, (1, First))  (Goal, (1, Second))  \
# 0            100.000000                  20                   20
# 1             97.142857                  20                   20
# 2             94.387755                  20                   20
# 3             91.731050                  20                   20
# 4             89.169226                  20                   20
#
#    (Goal, (2, First))  (Goal, (2, Second))  (Gap, (1, First))  ...  \
# 0                  20                   20           -80.0000  ...
# 1                  20                   20           -60.0000  ...
# 2                  20                   20           -45.0000  ...
# 3                  20                   20           -33.7500  ...
# 4                  20                   20           -25.3125  ...
#
#    (Gap, (2, First))  (Gap, (2, Second))  (AT, (1, First))  (AT, (1, Second))  \
# 0           -80.0000          -80.000000                 1                  3
# 1           -76.0000          -77.142857                 1                  3
# 2           -72.2000          -74.387755                 1                  3
# 3           -68.5900          -71.731050                 1                  3
# 4           -65.1605          -69.169226                 1                  3
#
#    (AT, (2, First))  (AT, (2, Second))  (Flow, (1, First))  \
# 0                 5                  7            -80.0000
# 1                 5                  7            -60.0000
# 2                 5                  7            -45.0000
# 3                 5                  7            -33.7500
# 4                 5                  7            -25.3125
#
#    (Flow, (1, Second))  (Flow, (2, First))  (Flow, (2, Second))
# 0           -26.666667            -16.0000           -11.428571
# 1           -24.444444            -15.2000           -11.020408
# 2           -22.407407            -14.4400           -10.626822
# 3           -20.540123            -13.7180           -10.247293
# 4           -18.828447            -13.0321            -9.881318
#
# [5 rows x 21 columns]

# %%
# df_outcome[['Goal', 'Stock']].plot()
df_outcome.plot()
# Out:
# <AxesSubplot:>
