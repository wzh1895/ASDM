# %%
from ASDM.Engine import Structure

# %%
# model = Structure(from_xmile='BuiltInTestModels/Goal_gap.stmx')
# model = Structure(from_xmile='BuiltInTestModels/Goal_gap_array.stmx')
# model = Structure(from_xmile='BuiltInTestModels/Built_in_vars.stmx')
# model = Structure(from_xmile='BuiltInTestModels/IF_THEN_ELSE.stmx')
# model = Structure(from_xmile='BuiltInTestModels/Graph_function.stmx ')
# model = Structure(from_xmile='BuiltInTestModels/Conveyor.stmx ')
# model = Structure(from_xmile='BuiltInTestModels/Array_cross_reference.stmx ')
# model = Structure(from_xmile='BuiltInTestModels/Delays.stmx ')
model = Structure(from_xmile='BuiltInTestModels/Logic.stmx ')
# Out:
# Engine: adding element: in1 equation: 2>1
# Engine: adding element: in2 equation: 3>2
# Engine: adding element: out1 equation: in1 AND in2
# Engine: adding element: in3 equation: 2>1
# Engine: adding element: in4 equation: 3>4
# Engine: adding element: out2 equation: in3 AND in4
# Engine: adding element: out3 equation: out1 OR out2

# %%
model.clear_last_run()
model.simulate()
df_outcome = model.export_simulation_result()
df_outcome
# Out:
#      TIME   in1   in2  out1   in3    in4   out2  out3
# 0    1.00  True  True  True  True  False  False  True
# 1    1.25  True  True  True  True  False  False  True
# 2    1.50  True  True  True  True  False  False  True
# 3    1.75  True  True  True  True  False  False  True
# 4    2.00  True  True  True  True  False  False  True
# 5    2.25  True  True  True  True  False  False  True
# 6    2.50  True  True  True  True  False  False  True
# 7    2.75  True  True  True  True  False  False  True
# 8    3.00  True  True  True  True  False  False  True
# 9    3.25  True  True  True  True  False  False  True
# 10   3.50  True  True  True  True  False  False  True
# 11   3.75  True  True  True  True  False  False  True
# 12   4.00  True  True  True  True  False  False  True
# 13   4.25  True  True  True  True  False  False  True
# 14   4.50  True  True  True  True  False  False  True
# 15   4.75  True  True  True  True  False  False  True
# 16   5.00  True  True  True  True  False  False  True
# 17   5.25  True  True  True  True  False  False  True
# 18   5.50  True  True  True  True  False  False  True
# 19   5.75  True  True  True  True  False  False  True
# 20   6.00  True  True  True  True  False  False  True
# 21   6.25  True  True  True  True  False  False  True
# 22   6.50  True  True  True  True  False  False  True
# 23   6.75  True  True  True  True  False  False  True
# 24   7.00  True  True  True  True  False  False  True
# 25   7.25  True  True  True  True  False  False  True
# 26   7.50  True  True  True  True  False  False  True
# 27   7.75  True  True  True  True  False  False  True
# 28   8.00  True  True  True  True  False  False  True
# 29   8.25  True  True  True  True  False  False  True
# 30   8.50  True  True  True  True  False  False  True
# 31   8.75  True  True  True  True  False  False  True
# 32   9.00  True  True  True  True  False  False  True
# 33   9.25  True  True  True  True  False  False  True
# 34   9.50  True  True  True  True  False  False  True
# 35   9.75  True  True  True  True  False  False  True
# 36  10.00  True  True  True  True  False  False  True
# 37  10.25  True  True  True  True  False  False  True
# 38  10.50  True  True  True  True  False  False  True
# 39  10.75  True  True  True  True  False  False  True
# 40  11.00  True  True  True  True  False  False  True
# 41  11.25  True  True  True  True  False  False  True
# 42  11.50  True  True  True  True  False  False  True
# 43  11.75  True  True  True  True  False  False  True
# 44  12.00  True  True  True  True  False  False  True
# 45  12.25  True  True  True  True  False  False  True
# 46  12.50  True  True  True  True  False  False  True
# 47  12.75  True  True  True  True  False  False  True
# 48  13.00  True  True  True  True  False  False  True

# %%
# df_outcome[['Goal', 'Stock']].plot()
df_outcome.plot()
# Out:
# <AxesSubplot:>
