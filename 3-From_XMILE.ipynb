# %%
from ASDM.Engine import Structure

# %%
# model = Structure(from_xmile='BuiltInTestModels/Goal_gap.stmx')
model = Structure(from_xmile='BuiltInTestModels/Goal_gap_array.stmx')
# model = Structure(from_xmile='BuiltInTestModels/Built_in_vars.stmx')
# model = Structure(from_xmile='BuiltInTestModels/IF_THEN_ELSE.stmx')
# model = Structure(from_xmile='BuiltInTestModels/Graph_function.stmx ')
# Out:
# {'Dim1': ['1', '2'], 'Dim2': ['First', 'Second']}
# Engine: adding element: Stock equation: <ASDM.Engine.SubscriptIndexer object at 0x000002ABCBF095E0>
# Engine: adding element: Goal equation: 20
# Engine: adding element: Gap equation: <ASDM.Engine.SubscriptIndexer object at 0x000002ABCBF87A30>
# Engine: adding element: AT equation: <ASDM.Engine.SubscriptIndexer object at 0x000002ABCBF87A30>
# Engine: adding element: Flow equation: <ASDM.Engine.SubscriptIndexer object at 0x000002ABCBF87A30>

# %%
model.clear_last_run()
model.simulate()
df_outcome = model.export_simulation_result()
df_outcome
# Out:
#      TIME  (Stock, (1, First))  (Stock, (1, Second))  (Stock, (2, First))  \
# 0    0.00             100.0000            100.000000           100.000000
# 1    0.25              80.0000             93.333333            96.000000
# 2    0.50              65.0000             87.222222            92.200000
# 3    0.75              53.7500             81.620370            88.590000
# 4    1.00              45.3125             76.485340            85.160500
# ..    ...                  ...                   ...                  ...
# 76  19.00              20.0000             20.107438            21.622124
# 77  19.25              20.0000             20.098485            21.541018
# 78  19.50              20.0000             20.090278            21.463967
# 79  19.75              20.0000             20.082755            21.390768
# 80  20.00              20.0000             20.075859            21.321230
#
#     (Stock, (2, Second))  (Goal, (1, First))  (Goal, (1, Second))  \
# 0             100.000000                  20                   20
# 1              97.142857                  20                   20
# 2              94.387755                  20                   20
# 3              91.731050                  20                   20
# 4              89.169226                  20                   20
# ..                   ...                 ...                  ...
# 76             25.043426                  20                   20
# 77             24.863304                  20                   20
# 78             24.689615                  20                   20
# 79             24.522128                  20                   20
# 80             24.360624                  20                   20
#
#     (Goal, (2, First))  (Goal, (2, Second))  (Gap, (1, First))  ...  \
# 0                   20                   20      -8.000000e+01  ...
# 1                   20                   20      -6.000000e+01  ...
# 2                   20                   20      -4.500000e+01  ...
# 3                   20                   20      -3.375000e+01  ...
# 4                   20                   20      -2.531250e+01  ...
# ..                 ...                  ...                ...  ...
# 76                  20                   20      -2.557090e-08  ...
# 77                  20                   20      -1.917817e-08  ...
# 78                  20                   20      -1.438363e-08  ...
# 79                  20                   20      -1.078772e-08  ...
# 80                  20                   20      -8.090794e-09  ...
#
#     (Gap, (2, First))  (Gap, (2, Second))  (AT, (1, First))  \
# 0          -80.000000          -80.000000                 1
# 1          -76.000000          -77.142857                 1
# 2          -72.200000          -74.387755                 1
# 3          -68.590000          -71.731050                 1
# 4          -65.160500          -69.169226                 1
# ..                ...                 ...               ...
# 76          -1.622124           -5.043426                 1
# 77          -1.541018           -4.863304                 1
# 78          -1.463967           -4.689615                 1
# 79          -1.390768           -4.522128                 1
# 80          -1.321230           -4.360624                 1
#
#     (AT, (1, Second))  (AT, (2, First))  (AT, (2, Second))  \
# 0                   3                 5                  7
# 1                   3                 5                  7
# 2                   3                 5                  7
# 3                   3                 5                  7
# 4                   3                 5                  7
# ..                ...               ...                ...
# 76                  3                 5                  7
# 77                  3                 5                  7
# 78                  3                 5                  7
# 79                  3                 5                  7
# 80                  3                 5                  7
#
#     (Flow, (1, First))  (Flow, (1, Second))  (Flow, (2, First))  \
# 0        -8.000000e+01           -26.666667          -16.000000
# 1        -6.000000e+01           -24.444444          -15.200000
# 2        -4.500000e+01           -22.407407          -14.440000
# 3        -3.375000e+01           -20.540123          -13.718000
# 4        -2.531250e+01           -18.828447          -13.032100
# ..                 ...                  ...                 ...
# 76       -2.557090e-08            -0.035813           -0.324425
# 77       -1.917817e-08            -0.032828           -0.308204
# 78       -1.438363e-08            -0.030093           -0.292793
# 79       -1.078772e-08            -0.027585           -0.278154
# 80       -8.090794e-09            -0.025286           -0.264246
#
#     (Flow, (2, Second))
# 0            -11.428571
# 1            -11.020408
# 2            -10.626822
# 3            -10.247293
# 4             -9.881318
# ..                  ...
# 76            -0.720489
# 77            -0.694758
# 78            -0.669945
# 79            -0.646018
# 80            -0.622946
#
# [81 rows x 21 columns]

# %%
# df_outcome[['Goal', 'Stock']].plot()
df_outcome.plot()
# Out:
# <AxesSubplot:>
